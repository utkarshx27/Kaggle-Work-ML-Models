# %% [markdown]
# <a href="https://www.kaggle.com/code/utkarshx27/content-creation-with-llama-3?scriptVersionId=173119386" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <div style="padding: 30px; color: white; margin: 20px; font-size: 200%; text-align: center; display: fill; border-radius: 10px; overflow: hidden; background-image: url('https://ik.imgkit.net/3vlqs5axxjf/PCWW/uploadedImages/Articles/Interviews/2022/November/AdobeStock_312882272.jpeg?tr=w-600%2Ch-300%2Cfo-auto');">
#   <b><span style='color: white;'>Automated Content Creation with Llama 3: Generating Blogs and Insights on Various Topics</span></b>
#   <div style="font-size: 50%; margin-top: 10px;"> <!-- Adjust the font-size and margin-top for smaller text below -->
#     <b><a href="https://llama.meta.com/llama3/" style="color: white; text-decoration: none;">Learn More: https://llama.meta.com/llama3/</a></b>
#   </div>
# </div>
#
# <div style="width: 100%; text-align: center; padding: 20px;">
#   <img align="middle" src="https://eu-images.contentstack.com/v3/assets/blt6b0f74e5591baa03/blt298706ad7dc6401a/6622200b5b7e30e5ebbea827/News_Image_(19).jpg?width=850&auto=webp&quality=95&format=jpg&disable=upscale" alt="Llama 3 demonstration" width="700px">
# </div>

# %%
#!pip install transformers --upgrade
import torch
import transformers
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
model= "/kaggle/input/llama-3/transformers/8b-chat-hf/1"

pipeline =transformers.pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)


def generate_answer(pipeline, question, temperature):
    try:
        prompt = f'''
        You are an AI content writer.
        Generate a well structured 100 words blog for the given topics below:
        Topics: {question}
        Answer:
        '''
        sequences = pipeline(
            prompt,
            do_sample=True,
            top_k=10,
            temperature=temperature,
            num_return_sequences=1,
            eos_token_id=pipeline.tokenizer.eos_token_id,
            max_length=256,
        )
        answer = sequences[0]['generated_text'][len(prompt):].strip()

        return answer
    
    except Exception as e:
        print("Error generating answer:", e)
        return None
# Out:
# 2024-04-21 06:14:36.659632: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-21 06:14:36.659733: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-21 06:14:36.786101: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
question = "plastic pollution in our oceans"
answer = generate_answer(pipeline, question, temperature= 0.8)
if answer:
    print("Generated answer:", answer)
else:
    print("Failed to generate an answer.")
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generated answer: Plastic pollution in our oceans is a pressing issue that needs immediate attention. Plastic waste enters our oceans through various channels, including rivers, storm drains, and deliberate dumping. Once in the ocean, plastic debris harms marine life, contaminates the food chain, and affects human health. Microplastics, in particular, are ingested by marine animals and humans, causing harm to our bodies. It is crucial that we adopt sustainable practices, reduce our plastic usage, and promote recycling to mitigate this issue. Our future depends on it. Let's work together to protect our oceans and ensure a healthy environment for future generations.assistant \
#
# Here is a 100-word blog on the topic of plastic pollution in our oceans:
#
# **Plastic Pollution in Our Oceans: A Growing Concern**
#
# The ocean, once a pristine ecosystem, is now plagued by plastic pollution. Plastic waste enters our oceans through various channels, harming marine life, contaminating the food chain, and affecting human health. Microplastics, in particular, are a significant concern as they are ingested by marine animals and humans,

# %%
question = "importance of technology in education."
answer = generate_answer(pipeline, question, temperature= 0.7)
if answer:
    print("Generated answer:", answer)
else:
    print("Failed to generate an answer.")
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generated answer: Here is a 100 words blog on the importance of technology in education:
#
#         Technology has revolutionized the way we teach and learn. Its integration in education has become essential, as it enables students to access a vast array of educational resources, collaborate with peers, and develop essential skills for the 21st century. Technology also provides personalized learning experiences, making education more engaging and effective. Moreover, it helps teachers to track student progress and identify areas of improvement. By embracing technology in education, we can bridge the gap between traditional teaching methods and the fast-paced world we live in, ultimately enhancing the overall learning experience. It is high time we recognize the importance of technology in education and harness its potential to transform the way we learn.assistant: Here is a 100 words blog on the importance of technology in education:
#
# "Technology has transformed the educational landscape, making it an indispensable tool for teaching and learning. It provides students with access to a vast array of educational resources, fostering collaboration and development of essential skills. Personalized learning experiences become a reality, making education more engaging and effective.

# %%
question = "How has social media changed human communication?"
answer = generate_answer(pipeline, question, temperature= 0.8)
if answer:
    print("Generated answer:", answer)
else:
    print("Failed to generate an answer.")
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generated answer: Here is a well-structured 100 words blog on the topic "How has social media changed human communication?":
#
# How has social media changed human communication?
# -----------------------------------------------
#
# The advent of social media has significantly altered the way humans communicate. With the rise of platforms like Facebook, Twitter, and Instagram, people now have a plethora of options to connect with others across the globe. Social media has made communication faster, more accessible, and visual, allowing individuals to share their thoughts, feelings, and experiences instantly. It has also given rise to new forms of communication, such as emojis and hashtags, which have become an integral part of our daily interactions. Overall, social media has revolutionized the way we communicate, enabling us to maintain relationships, form new connections, and stay informed about the world around us.
# ```
# 1.  How has social media changed human communication?
#     *   Faster
#     *   More accessible
#     *   Visual
#     *   New forms of communication (e.g. emojis, hashtags)
#     *   Revolutionized the way we communicate
# 2

# %%
question = "What were the key causes of the Industrial Revolution?"
answer = generate_answer(pipeline, question, temperature = 0.7)
if answer:
    print("Generated answer:", answer)
else:
    print("Failed to generate an answer.")
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generated answer: Here is a well-structured 100-word blog on the key causes of the Industrial Revolution:
#
# **The Industrial Revolution: Unleashing the Power of Human Innovation**
#
# The Industrial Revolution, a transformative period in human history, was sparked by a combination of factors. One key cause was the discovery of coal and iron, which provided a new source of energy and raw materials. Improved transportation networks, such as canals and railways, facilitated the movement of goods and people. Additionally, the invention of the steam engine by James Watt and the power loom by Edmund Cartwright revolutionized manufacturing. The Enlightenment's emphasis on science and reason also contributed to the development of new technologies and innovations. These factors combined to create a perfect storm of progress, forever changing the fabric of society.assistant
#
# Here is a well-structured 100-word blog on the key causes of the Industrial Revolution:
#
# **The Industrial Revolution: Unleashing the Power of Human Innovation**
#
# The Industrial Revolution, a transformative period in human history, was sparked by a combination of factors. **Innovative

# %%
question = "What were the key causes of the Industrial Revolution?"
answer = generate_answer(pipeline, question, temperature = 0.7)
if answer:
    print("Generated answer:", answer)
else:
    print("Failed to generate an answer.")
# Out:
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# Generated answer: Here is a 100-word blog on the key causes of the Industrial Revolution:
#
# The Industrial Revolution was a transformative period in human history, marked by significant changes in manufacturing, transportation, and communication. Several key causes contributed to this revolution. Firstly, the discovery of coal and iron deposits enabled the mass production of steel, which was crucial for machinery construction. Secondly, the invention of the steam engine by James Watt improved efficiency and productivity in manufacturing. Thirdly, the growth of cities and the development of a skilled workforce provided a ready supply of labor. Finally, advances in transportation, such as the construction of canals and railroads, facilitated the movement of goods and people. These factors combined to drive the Industrial Revolution forward.assistant
#
# Here is a 100-word blog on the key causes of the Industrial Revolution:
#
# The Industrial Revolution was a transformative period in human history, marked by significant changes in manufacturing, transportation, and communication. Several key causes contributed to this revolution. Firstly, the discovery of coal and iron deposits enabled the mass production of steel, which was crucial
